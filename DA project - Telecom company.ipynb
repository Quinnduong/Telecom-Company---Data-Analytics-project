# %% [markdown]
# Here, we have analyzed the dataset of an European Telecom Company.
#
# This Telecom's Attrition Dataset, consists of cleaned customer activity data (features), along with a churn label specifying whether a customer cancelled the subscription.
#
# We explore and analyze the data to discover key factors responsible for customer attrition and come up with ways/recommendations to ensure customer retention.

# %% [markdown]
# # Business Understanding Of A Telecom Industry Customer Attrition:
#
# Customer attrition is a big problem in any industry and one of the most important concerns for the Telecom industry.
#
# The effect on the revenues of the companies, because of this customer attrition is huge, especially in the telecom field, that's why these companies are seeking to develop a predictive potential customer attrition.
#
# In this highly competitive market, the telecommunications industry experiences an average of 15-25% annual attrition rate, and it costs 5-10 times more to acquire a new customer than to retain an existing one, that's why customer retention has now become even more important than customer acquisition.
#
# Therefore, finding those factors that increase customer attrition is important to take necessary actions to reduce this attrition.
#
# ##### The main goal of our project is to develop an understanding of the cause of customer attrition which assists telecom operators to predict customers who are most likely subject to attrition, and what to do to retain the most valuable customer.

# %% [markdown]
# #### We will find how we can maximize the profit by retaining customer, and, how we can reduce the attrition rate by identifying the issues.

# %%
import pandas as pd                        # To import the Pandas library
import seaborn as sns                      # To import the Seaborn library
import matplotlib.pyplot as plt            # To import the Matplotlib library 
# %matplotlib inline

# %%
data = pd.read_csv("Documents/Data Analytics Projects/Telecom Dataset.csv")

# %% [markdown]
# # Exploring the Dataset

# %%
data
# Out:
#      state  account length  area code phone number international plan  \
# 0       KS             128        415     382-4657                 no
# 1       OH             107        415     371-7191                 no
# 2       NJ             137        415     358-1921                 no
# 3       OH              84        408     375-9999                yes
# 4       OK              75        415     330-6626                yes
# ...    ...             ...        ...          ...                ...
# 3328    AZ             192        415     414-4276                 no
# 3329    WV              68        415     370-3271                 no
# 3330    RI              28        510     328-8230                 no
# 3331    CT             184        510     364-6381                yes
# 3332    TN              74        415     400-4344                 no
#
#      voice mail plan  number vmail messages  total day minutes  \
# ...

# %%
data.head()
# Out:
#   state  account length  area code phone number international plan  \
# 0    KS             128        415     382-4657                 no
# 1    OH             107        415     371-7191                 no
# 2    NJ             137        415     358-1921                 no
# 3    OH              84        408     375-9999                yes
# 4    OK              75        415     330-6626                yes
#
#   voice mail plan  number vmail messages  total day minutes  total day calls  \
# 0             yes                     25              265.1              110
# 1             yes                     26              161.6              123
# 2              no                      0              243.4              114
# 3              no                      0              299.4               71
# 4              no                      0              166.7              113
#
#    total day charge  ...  total eve calls  total eve charge  \
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3333 entries, 0 to 3332
# Data columns (total 21 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   state                   3333 non-null   object
#  1   account length          3333 non-null   int64
#  2   area code               3333 non-null   int64
#  3   phone number            3333 non-null   object
#  4   international plan      3333 non-null   object
#  5   voice mail plan         3333 non-null   object
#  6   number vmail messages   3333 non-null   int64
#  7   total day minutes       3333 non-null   float64
#  8   total day calls         3333 non-null   int64
#  9   total day charge        3333 non-null   float64
#  10  total eve minutes       3333 non-null   float64
#  11  total eve calls         3333 non-null   int64
#  12  total eve charge        3333 non-null   float64
#  13  total night minutes     3333 non-null   float64
# ...

# %%
data.nunique()
# Out:
# state                       51
# account length             212
# area code                    3
# phone number              3333
# international plan           2
# voice mail plan              2
# number vmail messages       46
# total day minutes         1667
# total day calls            119
# total day charge          1667
# total eve minutes         1611
# total eve calls            123
# total eve charge          1440
# total night minutes       1591
# total night calls          120
# total night charge         933
# total intl minutes         162
# total intl calls            21
# total intl charge          162
# customer service calls      10
# churn                        2
# dtype: int64

# %%
data.columns
# Out:
# Index(['state', 'account length', 'area code', 'phone number',
#        'international plan', 'voice mail plan', 'number vmail messages',
#        'total day minutes', 'total day calls', 'total day charge',
#        'total eve minutes', 'total eve calls', 'total eve charge',
#        'total night minutes', 'total night calls', 'total night charge',
#        'total intl minutes', 'total intl calls', 'total intl charge',
#        'customer service calls', 'churn'],
#       dtype='object')

# %%
data.dtypes
# Out:
# state                      object
# account length              int64
# area code                   int64
# phone number               object
# international plan         object
# voice mail plan            object
# number vmail messages       int64
# total day minutes         float64
# total day calls             int64
# total day charge          float64
# total eve minutes         float64
# total eve calls             int64
# total eve charge          float64
# total night minutes       float64
# total night calls           int64
# total night charge        float64
# total intl minutes        float64
# total intl calls            int64
# total intl charge         float64
# customer service calls      int64
# churn                        bool
# dtype: object

# %%
data.describe()
# Out:
#        account length    area code  number vmail messages  total day minutes  \
# count     3333.000000  3333.000000            3333.000000        3333.000000
# mean       101.064806   437.182418               8.099010         179.775098
# std         39.822106    42.371290              13.688365          54.467389
# min          1.000000   408.000000               0.000000           0.000000
# 25%         74.000000   408.000000               0.000000         143.700000
# 50%        101.000000   415.000000               0.000000         179.400000
# 75%        127.000000   510.000000              20.000000         216.400000
# max        243.000000   510.000000              51.000000         350.800000
#
#        total day calls  total day charge  total eve minutes  total eve calls  \
# count      3333.000000       3333.000000        3333.000000      3333.000000
# mean        100.435644         30.562307         200.980348       100.114311
# ...

# %% [markdown]
# ## Checking missing and duplicat values

# %%
data.head(2)
# Out:
#   state  account length  area code phone number international plan  \
# 0    KS             128        415     382-4657                 no
# 1    OH             107        415     371-7191                 no
#
#   voice mail plan  number vmail messages  total day minutes  total day calls  \
# 0             yes                     25              265.1              110
# 1             yes                     26              161.6              123
#
#    total day charge  ...  total eve calls  total eve charge  \
# 0             45.07  ...               99             16.78
# 1             27.47  ...              103             16.62
#
#    total night minutes  total night calls  total night charge  \
# 0                244.7                 91               11.01
# 1                254.4                103               11.45
#
#    total intl minutes  total intl calls  total intl charge  \
# 0                10.0                 3                2.7
# ...

# %%
data.isna().sum()            # To show the count of missing (null) values in each column
# Out:
# state                     0
# account length            0
# area code                 0
# phone number              0
# international plan        0
# voice mail plan           0
# number vmail messages     0
# total day minutes         0
# total day calls           0
# total day charge          0
# total eve minutes         0
# total eve calls           0
# total eve charge          0
# total night minutes       0
# total night calls         0
# total night charge        0
# total intl minutes        0
# total intl calls          0
# total intl charge         0
# customer service calls    0
# churn                     0
# dtype: int64

# %%
data[data.duplicated()]          # To show the duplicate records present in the DataFrame
                                 # In this dataframe, no duplicate records present
# Out:
# Empty DataFrame
# Columns: [state, account length, area code, phone number, international plan, voice mail plan, number vmail messages, total day minutes, total day calls, total day charge, total eve minutes, total eve calls, total eve charge, total night minutes, total night calls, total night charge, total intl minutes, total intl calls, total intl charge, customer service calls, churn]
# Index: []
#
# [0 rows x 21 columns]

# %%
data = data.drop_duplicates()    # To drop all the duplicate records from the DataFrame, and saving the updated DF

# %% [markdown]
# # 1. Analyzing the 'churn' Variable

# %%
data['churn'].unique()
# Out:
# array([False,  True])

# %%
A = data['churn'].value_counts()     # To show the count of the unique values of the column 'churn' ...
print(A)
# Out:
# churn
# False    2850
# True      483
# Name: count, dtype: int64

# %%
str(483/3333*100) + " %"             # Just to check the percentage of True (churned customers) from the dataset ...
                                     # ... and showing the result in string format, after adding % sign at the end
# Out:
# '14.491449144914492 %'

# %% [markdown]
# ### Donut Chart

# %%
# Creating a Donut Chart for Churn vs Non-Churn Customers

plt.pie(A, labels=['Not Churned', 'Churned'], colors=['orange','lime'], startangle=50, shadow=True, radius=2, 
        explode=(0,0.2), autopct='%1.2f%%', pctdistance=0.75);
circle = plt.Circle((0,0), 1, color='white')
c = plt.gcf()

c.gca().add_artist(circle)

plt.title("Churned vs Non-Churned Customers (DSL)")
plt.show()

# %% [markdown]
# #### Countplot

# %%
# Countplot for Churn vs Non-Churn Customers

sns.countplot(x=data['churn']);

# %% [markdown]
# -------

# %% [markdown]
# Outcome -
#
# After analyzing the Churn column, we notice that almost 15% customers have churned. Now, we will analyze other columns to find out the possible reasons for this churn.

# %% [markdown]
# ## 2. Analyzing the 'State' Variable

# %%
data.state.nunique()
# Out:
# 51

# %%
data.state.value_counts()
# Out:
# state
# WV    106
# MN     84
# NY     83
# AL     80
# WI     78
# OH     78
# OR     78
# WY     77
# VA     77
# CT     74
# MI     73
# ID     73
# VT     73
# TX     72
# UT     72
# IN     71
# MD     70
# KS     70
# NC     68
# NJ     68
# MT     68
# CO     66
# NV     66
# WA     66
# RI     65
# MA     65
# MS     65
# AZ     64
# FL     63
# MO     63
# NM     62
# ME     62
# ND     62
# NE     61
# OK     61
# DE     61
# SC     60
# SD     60
# KY     59
# IL     58
# NH     56
# AR     55
# GA     54
# DC     54
# HI     53
# TN     53
# AK     52
# LA     51
# PA     45
# IA     44
# CA     34
# Name: count, dtype: int64

# %% [markdown]
# #### Countplot

# %%
plt.figure(figsize=(20,7))       # Setting the size of the figure as 20 x 7, using matplotlib library

sns.countplot(x = data['state'])    # Drawing a countplot for the column 'state' from the datset using seaborn library
plt.xticks(fontsize=13)         # Setting the fontsize of states on x-axis
plt.yticks(fontsize=13)         # Setting the fontsize of numbers on y-axis
plt.xlabel('States', fontsize=20, color='Red')       # Setting the label on x-axis as States , its fontsize , its color
plt.ylabel('Count', fontsize=20, color='Green')      # Setting the label on y-axis as Count , its fontsize , its color
plt.show()                                           # To display the figure

# %%
# Showing Churn/Not Churn State-wise

sns.set(style="whitegrid")           # Using seaborn library, setting the background of the figure as "whitegrid"

plt.figure(figsize=(20,7))           # Setting the size of the figure as 20 x 7, using matplotlib library

sns.countplot(x=data.state, hue = data.churn)    

plt.xlabel('States', fontsize=18, color='DarkBlue')   # Setting the Label on x-axis as States, its fontsize & color
plt.ylabel('Count', fontsize=18, color='DarkOrange'); # Setting the Label on y-axis as Count , its fontsize & color

# %%
a = data.groupby("state")['churn'].mean()*100

a.sort_values()
# Out:
# state
# HI     5.660377
# AK     5.769231
# AZ     6.250000
# VA     6.493506
# IA     6.818182
# LA     7.843137
# NE     8.196721
# IL     8.620690
# WI     8.974359
# RI     9.230769
# DC     9.259259
# TN     9.433962
# WV     9.433962
# NM     9.677419
# ND     9.677419
# AL    10.000000
# VT    10.958904
# MO    11.111111
# WY    11.688312
# ID    12.328767
# IN    12.676056
# FL    12.698413
# OH    12.820513
# SD    13.333333
# KY    13.559322
# CO    13.636364
# UT    13.888889
# OR    14.102564
# OK    14.754098
# DE    14.754098
# GA    14.814815
# NH    16.071429
# NC    16.176471
# CT    16.216216
# MA    16.923077
# PA    17.777778
# MN    17.857143
# NY    18.072289
# KS    18.571429
# AR    20.000000
# MT    20.588235
# ME    20.967742
# WA    21.212121
# NV    21.212121
# MS    21.538462
# MI    21.917808
# SC    23.333333
# MD    24.285714
# TX    25.000000
# NJ    26.470588
# CA    26.470588
# Name: churn, dtype: float64

# %% [markdown]
# ### Line Chart

# %%
# Drawing a Line Chart showing State-wise Churn rate

x = data.state.unique()      # Considering all unique values of 'state' column, and saving the output in variable X
y = data.groupby("state")['churn'].mean()    # Using groupby on 'state' column, and calculating the mean of churn ...
                                             # ... values against each state, and saving the output in variable Y
sns.set(style="darkgrid")               # Using seaborn library, setting the background of the figure as "whitegrid"

plt.rcParams['figure.figsize'] = (20,7)    # Using rcParams from matplotlib library ...
                                           # ... setting the size of the figure as 20 x 7
plt.rcParams['lines.linestyle'] = '-'      # Using rcParams from matplotlib library ...
                                           # ... setting the style of the line as ' - '
    
plt.plot(X, Y, color='green', marker = '*', markersize='10')    # Plotting a Line chart with X and Y ... 
# ... States showing on x-axis & Churn Rate showing on y-axis ... color of line set as 'black' ... 
# ... marker set as '*' ... markersize set as '10'

plt.title("State Churn Graph", fontsize=25)  # Using matplotlib, setting the Title of figure, with fontsize of 25
plt.xlabel("States", fontsize=20)            # Using matplotlib, setting the Label of x-axis, with fontsize of 20
plt.ylabel("Churn Rate", fontsize=20);       # Using matplotlib, setting the Label of y-axis, with fontsize of 20

# %%
data.groupby("state")['churn'].mean().sort_values(ascending=False).head(5)*100
# Out:
# state
# NJ    26.470588
# CA    26.470588
# TX    25.000000
# MD    24.285714
# SC    23.333333
# Name: churn, dtype: float64

# %%
# Calculatiog State vs Churn Percentage

c = pd.crosstab(data.state, data.churn ,margins=True)  
                                 # Using crosstab function from pandas library to compute a simple cross-tabulation...
                                 # ...of two columns i.e., 'state' & 'churn' and saving the output in varibale 'c'
                                 # ... margins=True means - to show the sum of both values in a new column 'All'
c['Percentage_Churn'] = c[True]/(c['All']) * 100       # Creating a new column 'Percantage_Churn', which shows the...
                                                       # ...percentage of churn customers in each state
print(c.head())                                        # Printing top 5 records of the result
print(type(c))                                         # Printing type of 'c' ; it's is a DataFrame
# Out:
# churn  False  True  All  Percentage_Churn
# state
# AK        49     3   52          5.769231
# AL        72     8   80         10.000000
# AR        44    11   55         20.000000
# AZ        60     4   64          6.250000
# CA        25     9   34         26.470588
# <class 'pandas.core.frame.DataFrame'>

# %%
c.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 52 entries, AK to All
# Data columns (total 4 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   False             52 non-null     int64
#  1   True              52 non-null     int64
#  2   All               52 non-null     int64
#  3   Percentage_Churn  52 non-null     float64
# dtypes: float64(1), int64(3)
# memory usage: 2.0+ KB

# %%
c.sort_values(by='Percentage_Churn', ascending = False).head()
# Out:
# churn  False  True  All  Percentage_Churn
# state
# CA        25     9   34         26.470588
# NJ        50    18   68         26.470588
# TX        54    18   72         25.000000
# MD        53    17   70         24.285714
# SC        46    14   60         23.333333

# %% [markdown]
# ## 3. Analyzing the 'Area Code' Column

# %%
data.head()
# Out:
#   state  account length  area code phone number international plan  \
# 0    KS             128        415     382-4657                 no
# 1    OH             107        415     371-7191                 no
# 2    NJ             137        415     358-1921                 no
# 3    OH              84        408     375-9999                yes
# 4    OK              75        415     330-6626                yes
#
#   voice mail plan  number vmail messages  total day minutes  total day calls  \
# 0             yes                     25              265.1              110
# 1             yes                     26              161.6              123
# 2              no                      0              243.4              114
# 3              no                      0              299.4               71
# 4              no                      0              166.7              113
#
#    total day charge  ...  total eve calls  total eve charge  \
# ...

# %%
data['area code'].nunique()
# Out:
# 3

# %%
data['area code'].unique()
# Out:
# array([415, 408, 510])

# %%
data['area code'].value_counts()
# Out:
# area code
# 415    1655
# 510     840
# 408     838
# Name: count, dtype: int64

# %%
data.groupby('area code')['churn'].mean() * 100
# Out:
# area code
# 408    14.558473
# 415    14.259819
# 510    14.880952
# Name: churn, dtype: float64

# %%
# Calculatiog Area Code vs Churn Percentage

d = pd.crosstab(data['area code'], data['churn'], margins= True)    
d['Churn Percentage'] = d[True]/(d['All']) * 100                     # Creating a new column 'Percantage_Churn'...
                                                   #...which shows the percentage of churn customers in each area code
d
# Out:
# churn      False  True   All  Churn Percentage
# area code
# 408          716   122   838         14.558473
# 415         1419   236  1655         14.259819
# 510          715   125   840         14.880952
# All         2850   483  3333         14.491449

# %%
# Drawing a Bar Graph to show Area Code wise Churn
 
plt.figure(figsize=(14,5))                      
# Setting the size of the figure as 14x5, using matplotlib library

sns.countplot(x='area code', hue='churn', data=data);

# %% [markdown]
# ----

# %% [markdown]
# ## 4. Analyzing the 'Account Length' Column

# %%
data.head()
# Out:
#   state  account length  area code phone number international plan  \
# 0    KS             128        415     382-4657                 no
# 1    OH             107        415     371-7191                 no
# 2    NJ             137        415     358-1921                 no
# 3    OH              84        408     375-9999                yes
# 4    OK              75        415     330-6626                yes
#
#   voice mail plan  number vmail messages  total day minutes  total day calls  \
# 0             yes                     25              265.1              110
# 1             yes                     26              161.6              123
# 2              no                      0              243.4              114
# 3              no                      0              299.4               71
# 4              no                      0              166.7              113
#
#    total day charge  ...  total eve calls  total eve charge  \
# ...

# %%
data['account length'].nunique()
# Out:
# 212

# %%
# Creating two different dataframes - one for 'churned customers' & second for 'non-churned customers'

churn_data = data[data['churn'] == True] 
not_churn_data = data[data['churn'] == False]

# %%
churn_data.head(2)
# Out:
#    state  account length  area code phone number international plan  \
# 10    IN              65        415     329-6603                 no
# 15    NY             161        415     351-7269                 no
#
#    voice mail plan  number vmail messages  total day minutes  total day calls  \
# 10              no                      0              129.1              137
# 15              no                      0              332.9               67
#
#     total day charge  ...  total eve calls  total eve charge  \
# 10             21.95  ...               83             19.42
# 15             56.59  ...               97             27.01
#
#     total night minutes  total night calls  total night charge  \
# 10                208.8                111                9.40
# 15                160.6                128                7.23
#
#     total intl minutes  total intl calls  total intl charge  \
# 10                12.7                 6               3.43
# ...

# %%
not_churn_data.head(2)
# Out:
#   state  account length  area code phone number international plan  \
# 0    KS             128        415     382-4657                 no
# 1    OH             107        415     371-7191                 no
#
#   voice mail plan  number vmail messages  total day minutes  total day calls  \
# 0             yes                     25              265.1              110
# 1             yes                     26              161.6              123
#
#    total day charge  ...  total eve calls  total eve charge  \
# 0             45.07  ...               99             16.78
# 1             27.47  ...              103             16.62
#
#    total night minutes  total night calls  total night charge  \
# 0                244.7                 91               11.01
# 1                254.4                103               11.45
#
#    total intl minutes  total intl calls  total intl charge  \
# 0                10.0                 3                2.7
# ...

# %%
churn_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 483 entries, 10 to 3323
# Data columns (total 21 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   state                   483 non-null    object
#  1   account length          483 non-null    int64
#  2   area code               483 non-null    int64
#  3   phone number            483 non-null    object
#  4   international plan      483 non-null    object
#  5   voice mail plan         483 non-null    object
#  6   number vmail messages   483 non-null    int64
#  7   total day minutes       483 non-null    float64
#  8   total day calls         483 non-null    int64
#  9   total day charge        483 non-null    float64
#  10  total eve minutes       483 non-null    float64
#  11  total eve calls         483 non-null    int64
#  12  total eve charge        483 non-null    float64
#  13  total night minutes     483 non-null    float64
# ...

# %%
data.shape
# Out:
# (3333, 21)

# %% [markdown]
# #### Distribution Plot

# %%
# Creating a Distribution Plot for Account Length column

sns.distplot(x=data['account length'], color='red')
plt.xlabel("Account Length", fontsize=15)
plt.ylabel("Density", fontsize=15)
plt.show()
# Out:
# /var/folders/rm/m8y4xjj93rg59bgp3b9hgd940000gn/T/ipykernel_55906/3601897587.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(x=data['account length'], color='red')

# %%
# Comparing Account Length of 'churned' and 'not churned' customers, using distplot

sns.distplot(x=data['account length'], color='black', label='All')
sns.distplot(x=churn_data['account length'], hist=False, color='red', label='Churned')
sns.distplot(x=not_churn_data['account length'], hist=False, color='yellow', label='Not Churned')
plt.xlabel("Account Length", fontsize=15)
plt.ylabel("Density", fontsize=15)
plt.rcParams['figure.figsize'] = (15,7);
plt.show()
# Out:
# /var/folders/rm/m8y4xjj93rg59bgp3b9hgd940000gn/T/ipykernel_55906/2777441702.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(x=data['account length'], color='black', label='All')
# /var/folders/rm/m8y4xjj93rg59bgp3b9hgd940000gn/T/ipykernel_55906/2777441702.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# ...

# %% [markdown]
# ----

# %% [markdown]
# ---

# %% [markdown]
# ## 5. Analyzing the 'International Plan' Column

# %%
data.head()
# Out:
#   state  account length  area code phone number international plan  \
# 0    KS             128        415     382-4657                 no
# 1    OH             107        415     371-7191                 no
# 2    NJ             137        415     358-1921                 no
# 3    OH              84        408     375-9999                yes
# 4    OK              75        415     330-6626                yes
#
#   voice mail plan  number vmail messages  total day minutes  total day calls  \
# 0             yes                     25              265.1              110
# 1             yes                     26              161.6              123
# 2              no                      0              243.4              114
# 3              no                      0              299.4               71
# 4              no                      0              166.7              113
#
#    total day charge  ...  total eve calls  total eve charge  \
# ...

# %%
data['international plan'].unique()
# Out:
# array(['no', 'yes'], dtype=object)

# %%
data['international plan'].value_counts()
# Out:
# international plan
# no     3010
# yes     323
# Name: count, dtype: int64

# %%
# Creating a new dataframe 'yes_int_plan',...
#...containing the records of those Churned customers who were having international plan

yes_int_plan = data[(data['international plan'] == 'yes') & (data['churn']==True)]
yes_int_plan
# Out:
#      state  account length  area code phone number international plan  \
# 41      MD             135        408     383-6029                yes
# 115     ME              36        510     363-1069                yes
# 144     VT             117        408     390-2390                yes
# 198     ME             131        510     353-7292                yes
# 214     FL              70        510     366-6345                yes
# ...    ...             ...        ...          ...                ...
# 3246    NC              77        408     334-6129                yes
# 3255    RI             138        510     411-6823                yes
# 3291    MI             119        510     335-7324                yes
# 3304    IL              71        510     330-7137                yes
# 3320    GA             122        510     411-5677                yes
#
#      voice mail plan  number vmail messages  total day minutes  \
# ...

# %%
no_int_plan = data[(data['international plan'] == 'no') & (data['churn']==True)]
no_int_plan
# Out:
#      state  account length  area code phone number international plan  \
# 10      IN              65        415     329-6603                 no
# 15      NY             161        415     351-7269                 no
# 21      CO              77        408     393-7984                 no
# 33      AZ              12        408     360-1596                 no
# 48      ID             119        415     398-1294                 no
# ...    ...             ...        ...          ...                ...
# 3280    AR              76        408     345-3614                 no
# 3287    KS             170        415     404-5840                 no
# 3301    CA              84        415     417-1488                 no
# 3322    MD              62        408     409-1856                 no
# 3323    IN             117        415     362-5899                 no
#
#      voice mail plan  number vmail messages  total day minutes  \
# ...

# %%
137/323*100
# Out:
# 42.414860681114554

# %%
346/3010*100
# Out:
# 11.495016611295682

# %%
int_plan_data = pd.crosstab(data['international plan'], data['churn'], margins=True)
int_plan_data
# Out:
# churn               False  True   All
# international plan
# no                   2664   346  3010
# yes                   186   137   323
# All                  2850   483  3333

# %%
int_plan_data['churn percent'] = int_plan_data[True]/int_plan_data['All']*100
int_plan_data
# Out:
# churn               False  True   All  churn percent
# international plan
# no                   2664   346  3010      11.495017
# yes                   186   137   323      42.414861
# All                  2850   483  3333      14.491449

# %%
i = data['international plan'].value_counts()
i
# Out:
# international plan
# no     3010
# yes     323
# Name: count, dtype: int64

# %% [markdown]
# ### Donut Chart

# %%
plt.pie(i, labels=['No', 'Yes'], colors=['yellow','cyan'], startangle=50, shadow=True, radius=2, 
        explode=(0,0.2), autopct='%1.2f%%',  pctdistance=0.75);
circle = plt.Circle((0,0), 1, color='white')
c = plt.gcf()

c.gca().add_artist(circle)

plt.title("International Plan (DSL)")
plt.rcParams['figure.figsize'] = (5,7)
plt.show()

# %% [markdown]
# #### Countplot

# %%
sns.countplot(x=data['international plan'], hue='churn', data=data)
plt.rcParams['figure.figsize'] = (10,4)
plt.show()

# %% [markdown]
# ## 6. Analyzing the 'Voice Mail Plan' column

# %%
data.head()
# Out:
#   state  account length  area code phone number international plan  \
# 0    KS             128        415     382-4657                 no
# 1    OH             107        415     371-7191                 no
# 2    NJ             137        415     358-1921                 no
# 3    OH              84        408     375-9999                yes
# 4    OK              75        415     330-6626                yes
#
#   voice mail plan  number vmail messages  total day minutes  total day calls  \
# 0             yes                     25              265.1              110
# 1             yes                     26              161.6              123
# 2              no                      0              243.4              114
# 3              no                      0              299.4               71
# 4              no                      0              166.7              113
#
#    total day charge  ...  total eve calls  total eve charge  \
# ...

# %% [markdown]
# #### Countplot

# %%
sns.countplot(x= data['voice mail plan'], hue="churn", data=data, color='green')
plt.rcParams['figure.figsize']=(10,5)
plt.show()

# %%
vmplan = pd.crosstab(data['voice mail plan'], data['churn'], margins=True)
vmplan
# Out:
# churn            False  True   All
# voice mail plan
# no                2008   403  2411
# yes                842    80   922
# All               2850   483  3333

# %%
vmplan['churn percent'] = vmplan[True] / vmplan['All'] * 100
vmplan
# Out:
# churn            False  True   All  churn percent
# voice mail plan
# no                2008   403  2411      16.715056
# yes                842    80   922       8.676790
# All               2850   483  3333      14.491449

# %%
data['voice mail plan'].unique()
# Out:
# array(['yes', 'no'], dtype=object)

# %%
v = data['voice mail plan'].value_counts()
v
# Out:
# voice mail plan
# no     2411
# yes     922
# Name: count, dtype: int64

# %% [markdown]
# ### Donut Chart

# %%
plt.pie(v, labels=['No','Yes'], startangle=90, shadow=True, radius=1.5, explode=(0,0.1), autopct='%1.2f%%')

circle = plt.Circle((0,0),0.8, color='white')
c = plt.gcf()

c.gca().add_artist(circle)

plt.title("voice mail plan DSL")
plt.show()

# %% [markdown]
# ## 7. Analyzing the 'Number Vmail Messages' Column

# %%
data.head()
# Out:
#   state  account length  area code phone number international plan  \
# 0    KS             128        415     382-4657                 no
# 1    OH             107        415     371-7191                 no
# 2    NJ             137        415     358-1921                 no
# 3    OH              84        408     375-9999                yes
# 4    OK              75        415     330-6626                yes
#
#   voice mail plan  number vmail messages  total day minutes  total day calls  \
# 0             yes                     25              265.1              110
# 1             yes                     26              161.6              123
# 2              no                      0              243.4              114
# 3              no                      0              299.4               71
# 4              no                      0              166.7              113
#
#    total day charge  ...  total eve calls  total eve charge  \
# ...

# %%
data['number vmail messages'].unique()
# Out:
# array([25, 26,  0, 24, 37, 27, 33, 39, 30, 41, 28, 34, 46, 29, 35, 21, 32,
#        42, 36, 22, 23, 43, 31, 38, 40, 48, 18, 17, 45, 16, 20, 14, 19, 51,
#        15, 11, 12, 47,  8, 44, 49,  4, 10, 13, 50,  9])

# %%
data['number vmail messages'].value_counts().head()
# Out:
# number vmail messages
# 0     2411
# 31      60
# 29      53
# 28      51
# 33      46
# Name: count, dtype: int64

# %%
data['number vmail messages'].describe()
# Out:
# count    3333.000000
# mean        8.099010
# std        13.688365
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%        20.000000
# max        51.000000
# Name: number vmail messages, dtype: float64

# %%
sns.distplot(data['number vmail messages']);
# Out:
# /var/folders/rm/m8y4xjj93rg59bgp3b9hgd940000gn/T/ipykernel_55906/3139572390.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data['number vmail messages']);

# %% [markdown]
# #### Box Plot

# %%
sns.boxplot(x='churn', y='number vmail messages', color='violet', meanline=True, showmeans=True, sym='r+', data=data)
                             # creating a box plot for the cdolumn 'number vmail messages' ... grouped by column 'churn'
plt.figure(figsize =(5, 5))  # Setting the size of the figure as 5x5, using matplotlib library
plt.show()

# %% [markdown]
# ---

# %% [markdown]
# ## 8. Analyzing the 'Customer Service Calls' column

# %%
data.head()
# Out:
#   state  account length  area code phone number international plan  \
# 0    KS             128        415     382-4657                 no
# 1    OH             107        415     371-7191                 no
# 2    NJ             137        415     358-1921                 no
# 3    OH              84        408     375-9999                yes
# 4    OK              75        415     330-6626                yes
#
#   voice mail plan  number vmail messages  total day minutes  total day calls  \
# 0             yes                     25              265.1              110
# 1             yes                     26              161.6              123
# 2              no                      0              243.4              114
# 3              no                      0              299.4               71
# 4              no                      0              166.7              113
#
#    total day charge  ...  total eve calls  total eve charge  \
# ...

# %%
data['customer service calls'].nunique()
# Out:
# 10

# %%
data['customer service calls'].unique()
# Out:
# array([1, 0, 2, 3, 4, 5, 7, 9, 6, 8])

# %%
data['customer service calls'].value_counts()
# Out:
# customer service calls
# 1    1181
# 2     759
# 0     697
# 3     429
# 4     166
# 5      66
# 6      22
# 7       9
# 9       2
# 8       2
# Name: count, dtype: int64

# %%
churn_data = data[data['churn']]   # creating a new dataframe 'churn_data', with the records of all churned customers
churn_data
# Out:
#      state  account length  area code phone number international plan  \
# 10      IN              65        415     329-6603                 no
# 15      NY             161        415     351-7269                 no
# 21      CO              77        408     393-7984                 no
# 33      AZ              12        408     360-1596                 no
# 41      MD             135        408     383-6029                yes
# ...    ...             ...        ...          ...                ...
# 3301    CA              84        415     417-1488                 no
# 3304    IL              71        510     330-7137                yes
# 3320    GA             122        510     411-5677                yes
# 3322    MD              62        408     409-1856                 no
# 3323    IN             117        415     362-5899                 no
#
#      voice mail plan  number vmail messages  total day minutes  \
# ...

# %%
churn_data['customer service calls'].value_counts()
# Out:
# customer service calls
# 1    122
# 0     92
# 2     87
# 4     76
# 3     44
# 5     40
# 6     14
# 7      5
# 9      2
# 8      1
# Name: count, dtype: int64

# %%
cscalls = pd.crosstab(data['customer service calls'], data['churn'], margins=True)
                    # Using crosstab function from pandas library to compute a simple cross-tabulation...
                    # ...of two columns i.e., 'customer service calls' & 'churn' and saving the output in varibale 'c'
                    # ... margins=True means - to show the sum of both values in a new column 'All'
cscalls['churn percent'] = cscalls[True] / cscalls['All'] * 100
                                    # Creating a new column 'churn percent', which shows the...
                                    # ...percentage of churn customers against each count of customer service calls
cscalls
# Out:
# churn                   False  True   All  churn percent
# customer service calls
# 0                         605    92   697      13.199426
# 1                        1059   122  1181      10.330229
# 2                         672    87   759      11.462451
# 3                         385    44   429      10.256410
# 4                          90    76   166      45.783133
# 5                          26    40    66      60.606061
# 6                           8    14    22      63.636364
# 7                           4     5     9      55.555556
# 8                           1     1     2      50.000000
# 9                           0     2     2     100.000000
# All                      2850   483  3333      14.491449

# %% [markdown]
# #### Count plot

# %%
sns.countplot(x= 'customer service calls', hue='churn', color='red', data=data)
plt.show()

# %% [markdown]
# ## 9. Analyzing the 'Per Minute Charge'

# %%
data.head()
# Out:
#   state  account length  area code phone number international plan  \
# 0    KS             128        415     382-4657                 no
# 1    OH             107        415     371-7191                 no
# 2    NJ             137        415     358-1921                 no
# 3    OH              84        408     375-9999                yes
# 4    OK              75        415     330-6626                yes
#
#   voice mail plan  number vmail messages  total day minutes  total day calls  \
# 0             yes                     25              265.1              110
# 1             yes                     26              161.6              123
# 2              no                      0              243.4              114
# 3              no                      0              299.4               71
# 4              no                      0              166.7              113
#
#    total day charge  ...  total eve calls  total eve charge  \
# ...

# %%
dc_pm = data['total day charge'].mean()/data['total day minutes'].mean()
# checking per minute day charge
ec_pm = data['total eve charge'].mean()/data['total eve minutes'].mean()
# checking per minute evening charge
nc_pm = data['total night charge'].mean()/data['total night minutes'].mean()
# checking per minute night charge
intc_pm = data['total intl charge'].mean()/data['total intl minutes'].mean()

# %%
print(dc_pm)     
print(ec_pm)     
print(nc_pm)     
print(intc_pm)
# Out:
# 0.17000300739130672
# 0.08500104871485778
# 0.04500041448440008
# 0.2700500279887107

# %% [markdown]
# ### Bar Plot

# %%
sns.barplot(x=['day','evening', 'night', 'int'], y=[dc_pm, ec_pm, nc_pm, intc_pm])
plt.show()
